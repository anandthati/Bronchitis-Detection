# %%
import torch
from torch import nn,optim
from torch.autograd import Variable
from matplotlib.pyplot import imshow
from PIL import Image
import numpy as np
import os
import torch.nn.functional as F
import pandas as pd
from sklearn.model_selection import train_test_split
from torchvision import datasets, transforms
import torchvision
import cv2

# %%
for file in os.listdir("./Train_Images/"):
    if file != '.ipynb_checkpoints':
        sample_image = Image.open("./Train_Images/"+file)
        sample_image=sample_image.resize((224,224),Image.ANTIALIAS)
        sample_image.save('./Resized_train/'+file,'png')

# %%
for file in os.listdir("./Test_Images/"):
    if file != '.ipynb_checkpoints':
        sample_image = Image.open("./Test_Images/"+file)
        sample_image=sample_image.resize((224,224),Image.ANTIALIAS)
        sample_image.save('./Resized_test/'+file,'png')

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 1)

    def forward(self, x):
        in_size = x.size(0)
        print(x,len(x))
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)

# %%
model = Net()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

img_px = list(sample_image.getdata())
df = pd.read_csv('Train_Labels.csv')

def train(epoch):
    model.train()
    for file in os.listdir("./Resized_train/"):
        file_name = file.split('.')[0]
        Data = df[df['Images']==file_name].values[0]
        print (Data[0],Data[1])
        data, target = Variable(torch.Tensor(list(Image.open("./Resized_train/"+file).getdata()))), Variable(torch.Tensor(Data[1]))
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data[0]))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        # sum up batch loss
        test_loss += F.nll_loss(output, target, size_average=False).data[0]
        # get the index of the max log-probability
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))


for epoch in range(1, 10):
    train(epoch)
test()
# Out:
# CR_0252 0
# tensor([ 195.,  232.,  246.,  ...,  175.,  170.,  172.]) 50176
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-113-3b090a4a615f> in <module>()
#      44
#      45 for epoch in range(1, 10):
# ---> 46     train(epoch)
#      47 test()
#
# <ipython-input-113-3b090a4a615f> in train(epoch)
#      14         data, target = Variable(torch.Tensor(list(Image.open("./Resized_train/"+file).getdata()))), Variable(torch.Tensor(Data[1]))
#      15         optimizer.zero_grad()
# ---> 16         output = model(data)
#      17         loss = F.nll_loss(output, target)
#      18         loss.backward()
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
# ...

# %%
df = pd.read_csv('Train_Labels.csv')
for file in os.listdir("./Train_Images/"):
    file_name = file.split('.')[0]
    Data = df[df['Images']==file_name].values[0]
    print (Data[0],Data[1])
# Out:
# CR_0252 0
# CR_0227 0
# CR_0019 0
# MR_0083 0
# CR_0314 0
# CR_0559 1
# CR_0135 0
# MR_0063 0
# CR_0594 1
# CR_0636 1
# CR_0592 1
# CR_0256 0
# MR_0173 1
# CR_0005 0
# CR_0655 1
# CR_0085 0
# CR_0257 0
# CR_0496 1
# CR_0639 1
# MR_0258 1
# CR_0163 0
# CR_0656 1
# CR_0407 1
# CR_0199 0
# MR_0071 0
# CR_0525 1
# CR_0463 1
# CR_0014 0
# CR_0423 1
# CR_0440 1
# CR_0578 1
# CR_0406 1
# CR_0554 1
# MR_0102 0
# MR_0086 0
# CR_0651 1
# CR_0523 1
# CR_0548 1
# CR_0519 1
# CR_0077 0
# MR_0049 0
# CR_0596 1
# CR_0570 1
# CR_0622 1
# CR_0090 0
# CR_0209 0
# CR_0212 0
# MR_0113 1
# CR_0192 0
# CR_0488 1
# CR_0239 0
# CR_0643 1
# MR_0082 0
# CR_0064 0
# CR_0102 0
# CR_0567 1
# CR_0054 0
# MR_0068 0
# CR_0278 0
# CR_0218 0
# CR_0164 0
# CR_0481 1
# MR_0096 0
# CR_0509 1
# CR_0619 1
# CR_0418 1
# MR_0060 0
# CR_0505 1
# CR_0603 1
# CR_0057 0
# CR_0206 0
# CR_0563 1
# CR_0500 1
# CR_0349 1
# CR_0201 0
# MR_0041 0
# CR_0542 1
# CR_0431 1
# CR_0616 1
# CR_0517 1
# CR_0279 0
# MR_0064 0
# CR_0483 1
# ...

# %%
criterion = torch.nn.MSELoss(size_average=False)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
